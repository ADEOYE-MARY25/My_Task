# %% [markdown]
# DATA INGESTION

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("import successesfull")
# Out:
# import successesfull

# %%
# load in the dataset
sales=pd.read_excel("eletronic_sales.xlsx")

# %%
# View a snapshot of your dataset
sales
# Out:
#          Date Branch Sales Agent Products  Units   Price
# 0  2014-09-01   Woji     Chinedu    Apple      2  125.00
# 1  2015-06-17   Woji       Emeka    Apple      5  125.00
# 2  2015-09-10   Woji     Ibrahim   Lenovo      7    1.29
# 3  2015-11-17   Woji        Tolu       HP     11    4.99
# 4  2015-10-31   Woji       Tonye   Lenovo     14    1.29
# 5  2014-02-26   Woji     Ibrahim   Compaq     27   19.99
# 6  2014-10-05   Woji      George       HP     28    8.99
# 7  2015-12-21   Woji       Tonye       HP     28    4.99
# 8  2014-02-09   Woji        Tolu   Lenovo     36    4.99
# 9  2015-08-07   Woji       Emeka     Dell     42   23.95
# 10 2015-01-15   Woji     Ibrahim       HP     46    8.99
# 11 2014-01-23   Woji       Emeka       HP     50   19.99
# 12 2015-03-24   Woji        Tolu     Dell     50    4.99
# 13 2015-05-14   Woji     Ibrahim   Lenovo     53    1.29
# 14 2015-07-21   Woji      George     Dell     55   12.49
# ...

# %%
df = sales

# df =df.columns
df
# Out:
#          Date Branch Sales Agent Products  Units   Price
# 0  2014-09-01   Woji     Chinedu    Apple      2  125.00
# 1  2015-06-17   Woji       Emeka    Apple      5  125.00
# 2  2015-09-10   Woji     Ibrahim   Lenovo      7    1.29
# 3  2015-11-17   Woji        Tolu       HP     11    4.99
# 4  2015-10-31   Woji       Tonye   Lenovo     14    1.29
# 5  2014-02-26   Woji     Ibrahim   Compaq     27   19.99
# 6  2014-10-05   Woji      George       HP     28    8.99
# 7  2015-12-21   Woji       Tonye       HP     28    4.99
# 8  2014-02-09   Woji        Tolu   Lenovo     36    4.99
# 9  2015-08-07   Woji       Emeka     Dell     42   23.95
# 10 2015-01-15   Woji     Ibrahim       HP     46    8.99
# 11 2014-01-23   Woji       Emeka       HP     50   19.99
# 12 2015-03-24   Woji        Tolu     Dell     50    4.99
# 13 2015-05-14   Woji     Ibrahim   Lenovo     53    1.29
# 14 2015-07-21   Woji      George     Dell     55   12.49
# ...

# %%
# add revenue column
# To create a new column, you start with creating the new columns as a variable name

# units X price = Revenue
# units * price = Revenue
sales["Revenue(N)"] = sales["Units"] * sales["Price"]


# round(parameter,2)
sales["Revenue(N)"] = round(sales["Units"]*sales["Price"] * 1000,2)

# %%
# View to see if the changes has been effected
sales.head()
# Out:
#         Date Branch Sales Agent Products  Units   Price  Revenue(N)
# 0 2014-09-01   Woji     Chinedu    Apple      2  125.00    250000.0
# 1 2015-06-17   Woji       Emeka    Apple      5  125.00    625000.0
# 2 2015-09-10   Woji     Ibrahim   Lenovo      7    1.29      9030.0
# 3 2015-11-17   Woji        Tolu       HP     11    4.99     54890.0
# 4 2015-10-31   Woji       Tonye   Lenovo     14    1.29     18060.0

# %%
# lets check data types
sales.dtypes
# Out:
# Date           datetime64[ns]
# Branch                 object
# Sales Agent            object
# Products               object
# Units                   int64
# Price                 float64
# Revenue(N)            float64
# dtype: object

# %%
# lets just plot this, its not important through
sales.dtypes.value_counts().plot(kind="bar", xlabel = "Data Types", ylabel = "count")
# Out:
# <Axes: xlabel='Data Types', ylabel='count'>

# %%
# lets work on our datatime to extract the month, year and week name
# using ".dt.year",".dt.month_name()",".day_name()

sales["year"] = sales["Date"].dt.year
sales["Month"] = sales["Date"].dt.month_name()
sales["week"] = sales["Date"].dt.day_name()

# %%
sales.head()
# Out:
#         Date Branch Sales Agent Products  Units   Price  Revenue(N)  year  \
# 0 2014-09-01   Woji     Chinedu    Apple      2  125.00    250000.0  2014
# 1 2015-06-17   Woji       Emeka    Apple      5  125.00    625000.0  2015
# 2 2015-09-10   Woji     Ibrahim   Lenovo      7    1.29      9030.0  2015
# 3 2015-11-17   Woji        Tolu       HP     11    4.99     54890.0  2015
# 4 2015-10-31   Woji       Tonye   Lenovo     14    1.29     18060.0  2015
#
#        Month       week
# 0  September     Monday
# 1       June  Wednesday
# 2  September   Thursday
# 3   November    Tuesday
# 4    October   Saturday

# %% [markdown]
# #### WORKING ON THE PKI'S

# %%
# importing your dataset, cleaning and preparing it for analysis

# working on my KPI( Key performance index of this data)

# 1. Total units sold

Total_goods_sold = sales["Units"].sum()
print(f"Total goods sold sold: {Total_goods_sold} units")
# Out:
# Total goods sold sold: 2121 units

# %%
# 2. Total Revenue

Total_Revenue = sales["Revenue(N)"].sum()
print(f"Total Revenue: N{Total_Revenue}")
# Out:
# Total Revenue: N19627880.0

# %%
# 3. Average Revenue per unit
## using "round() function to approximate to 2 decimal place"Adeoye_Mary_task14.ipynb
Average_revenue_per_unit = round( Total_Revenue / Total_goods_sold, 2)
print(f"Total Revenue per unit: N{Average_revenue_per_unit}")
# Out:
# Total Revenue per unit: N9254.07

# %%
# 4. Numbers of products
## using the .nunique() shows the number of unique values
Numbers_of_products = sales["Products"].nunique()
print(f"Numbers of products: {Numbers_of_products}")
# Out:
# Numbers of products: 5

# %%
#5. Numbers of sales Agents
Numbers_of_sales_agents = sales["Sales Agent"].nunique()
print(f"Numbers of Sales Agents: {Numbers_of_sales_agents}")
# Out:
# Numbers of Sales Agents: 11

# %% [markdown]
# ### B. Work on the data column

# %%
#  set index using the data column
sales.set_index("Date", inplace=True)

# %% [markdown]
# ####Class Task1: Calculate the Total Monthly revenue for year 2015 and plot the chart using 3 visualization packages in python

# %%
sales.year.unique()
# Out:
# array([2014, 2015], dtype=int32)

# %%
sales_2015 = sales[sales["year"] == 2015]
sales_2015
# Out:
#            Branch Sales Agent Products  Units   Price  Revenue(N)  year  \
# Date
# 2015-06-17   Woji       Emeka    Apple      5  125.00    625000.0  2015
# 2015-09-10   Woji     Ibrahim   Lenovo      7    1.29      9030.0  2015
# 2015-11-17   Woji        Tolu       HP     11    4.99     54890.0  2015
# 2015-10-31   Woji       Tonye   Lenovo     14    1.29     18060.0  2015
# 2015-12-21   Woji       Tonye       HP     28    4.99    139720.0  2015
# 2015-08-07   Woji       Emeka     Dell     42   23.95   1005900.0  2015
# 2015-01-15   Woji     Ibrahim       HP     46    8.99    413540.0  2015
# 2015-03-24   Woji        Tolu     Dell     50    4.99    249500.0  2015
# 2015-05-14   Woji     Ibrahim   Lenovo     53    1.29     68370.0  2015
# 2015-07-21   Woji      George     Dell     55   12.49    686950.0  2015
# 2015-04-10   Woji       Tonye   Lenovo     66    1.99    131340.0  2015
# 2015-05-31   Woji     Ibrahim       HP     80    8.99    719200.0  2015
# ...

# %%
#1.  Filtering
#2. Grouping
#3. Visuals

# lets start analysising this dataset for insights



# 1. Monthly revenue in 2015

# step1: Filter for 2015

sales_2015 = sales[sales["year"] == 2015] 
sales_2015.head(3)
# Out:
#            Branch Sales Agent Products  Units   Price  Revenue(N)  year  \
# Date
# 2015-06-17   Woji       Emeka    Apple      5  125.00    625000.0  2015
# 2015-09-10   Woji     Ibrahim   Lenovo      7    1.29      9030.0  2015
# 2015-11-17   Woji        Tolu       HP     11    4.99     54890.0  2015
#
#                 Month       week
# Date
# 2015-06-17       June  Wednesday
# 2015-09-10  September   Thursday
# 2015-11-17   November    Tuesday

# %%
# step2:
# I am using the .sort_index() to arrange the output, so the arrangement is done base on the index
Total_monthly_revenue = sales_2015.groupby("Month")["Revenue(N)"].sum().sort_index()
Total_monthly_revenue
# Out:
# Month
# April         610380.0
# August       1830900.0
# December     2018780.0
# February     1324960.0
# January       413540.0
# July          996330.0
# June          625000.0
# March         389430.0
# May           787570.0
# November       54890.0
# October      1157490.0
# September     160270.0
# Name: Revenue(N), dtype: float64

# %%
# I am using the .sort_values() to arrange the output, so the arrange is done base on the values
Total_monthly_revenue = sales_2015.groupby("Month")["Revenue(N)"].sum().sort_values(ascending= False)
Total_monthly_revenue
# Out:
# Month
# December     2018780.0
# August       1830900.0
# February     1324960.0
# October      1157490.0
# July          996330.0
# May           787570.0
# June          625000.0
# April         610380.0
# January       413540.0
# March         389430.0
# September     160270.0
# November       54890.0
# Name: Revenue(N), dtype: float64

# %%
#  lets put this in plot using pandas
Total_monthly_revenue.plot(kind= "bar", xlabel= "Month", ylabel = "Revenue(N)")
# Out:
# <Axes: xlabel='Month', ylabel='Revenue(N)'>

# %%
# lets use matplotlib
plt.bar(Total_monthly_revenue.index, Total_monthly_revenue.values)
plt.xlabel("month")
plt.ylabel("Revenue(N)")
plt.title("Monthly Revenue in 2015")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# Student Task1: Follow the same step and calculate the monthly  revenue for 2014 and plot that using the 3 visualization packages in python.

# %%
# 2. Total revenue by branch 

# lest check the branches we have first
sales["Branch"].unique()
# Out:
# array(['Woji', 'GRA', 'Town'], dtype=object)

# %%
Total_revenue_by_branch = sales.groupby("Branch")["Revenue(N)"].sum() .sort_values(ascending = False)
Total_revenue_by_branch
# Out:
# Branch
# Woji    11139070.0
# GRA      6002090.0
# Town     2486720.0
# Name: Revenue(N), dtype: float64

# %%
# PLOT THE CHART FOR TOTAL REVENUE BY BRANCH USING MATPLOTLIB
plt.pie(Total_revenue_by_branch.value, labels=Total)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2688\1383351927.py in ?()
#       1 # PLOT THE CHART FOR TOTAL REVENUE BY BRANCH USING MATPLOTLIB
# ----> 2 plt.pie(Total_revenue_by_branch.value, labels=Total)
#
# c:\Users\oluwatoyin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value'
