# %% [markdown]
# DATA INGESTION

# %%
# Task 18

# importing all the necessaries libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
data= pd.read_csv("possum.csv")

# %%
# to check the shape of the files
data.shape
# Out:
# (104, 14)

# %%
data.head(15)
# Out:
#     case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0      1     1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1      2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2      3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3      4     1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4      5     1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
# 5      6     1  Vic   f  1.0     93.1    54.8      90.5   35.5      73.2
# 6      7     1  Vic   m  2.0     95.3    58.2      89.5   36.0      71.5
# 7      8     1  Vic   f  6.0     94.8    57.6      91.0   37.0      72.7
# 8      9     1  Vic   f  9.0     93.4    56.3      91.5   37.0      72.4
# 9     10     1  Vic   f  6.0     91.8    58.0      89.5   37.5      70.9
# 10    11     1  Vic   f  9.0     93.3    57.2      89.5   39.0      77.2
# 11    12     1  Vic   f  5.0     94.9    55.6      92.0   35.5      71.7
# ...

# %%
data.tail(7)
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 97     98     7  other   m  5.0     93.2    68.6      84.0   35.0      65.6
# 98     99     7  other   f  3.0     93.3    56.2      86.5   38.5      64.8
# 99    100     7  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100   101     7  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# 101   102     7  other   f  6.0     92.4    55.0      89.0   38.0      63.5
# 102   103     7  other   m  4.0     91.5    55.2      82.5   36.5      62.9
# 103   104     7  other   f  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# 97       44.3  14.5   28.5   32.0
# 98       43.8  14.0   28.0   35.0
# 99       46.8  14.8   23.0   27.0
# 100      48.0  14.0   25.0   33.0
# 101      45.4  13.0   25.0   30.0
# 102      45.9  15.4   25.0   29.0
# 103      46.0  14.8   28.5   33.5

# %%
# check the number of columns present
data.columns
# Out:
# Index(['case', 'site', 'Pop', 'sex', 'age', 'hdlngth', 'skullw', 'totlngth',
#        'taill', 'footlgth', 'earconch', 'eye', 'chest', 'belly'],
#       dtype='object')

# %%
data.dtypes
# Out:
# case          int64
# site          int64
# Pop          object
# sex          object
# age         float64
# hdlngth     float64
# skullw      float64
# totlngth    float64
# taill       float64
# footlgth    float64
# earconch    float64
# eye         float64
# chest       float64
# belly       float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   case      104 non-null    int64
#  1   site      104 non-null    int64
#  2   Pop       104 non-null    object
#  3   sex       104 non-null    object
#  4   age       102 non-null    float64
#  5   hdlngth   104 non-null    float64
#  6   skullw    104 non-null    float64
#  7   totlngth  104 non-null    float64
#  8   taill     104 non-null    float64
#  9   footlgth  103 non-null    float64
#  10  earconch  104 non-null    float64
#  11  eye       104 non-null    float64
#  12  chest     104 non-null    float64
#  13  belly     104 non-null    float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 11.5+ KB

# %%
data['sex'].describe()
# Out:
# count     104
# unique      2
# top         m
# freq       61
# Name: sex, dtype: object

# %%
data.describe()
# Out:
#              case        site         age     hdlngth      skullw    totlngth  \
# count  104.000000  104.000000  102.000000  104.000000  104.000000  104.000000
# mean    52.500000    3.625000    3.833333   92.602885   56.883654   87.088462
# std     30.166206    2.349086    1.909244    3.573349    3.113426    4.310549
# min      1.000000    1.000000    1.000000   82.500000   50.000000   75.000000
# 25%     26.750000    1.000000    2.250000   90.675000   54.975000   84.000000
# 50%     52.500000    3.000000    3.000000   92.800000   56.350000   88.000000
# 75%     78.250000    6.000000    5.000000   94.725000   58.100000   90.000000
# max    104.000000    7.000000    9.000000  103.100000   68.600000   96.500000
#
#             taill    footlgth    earconch         eye       chest       belly
# count  104.000000  103.000000  104.000000  104.000000  104.000000  104.000000
# mean    37.009615   68.459223   48.130769   15.046154   27.000000   32.586538
# ...

# %% [markdown]
# DATA CLEANING

# %%
# Check for missng values
data.isna().sum()
# Out:
# case        0
# site        0
# Pop         0
# sex         0
# age         2
# hdlngth     0
# skullw      0
# totlngth    0
# taill       0
# footlgth    1
# earconch    0
# eye         0
# chest       0
# belly       0
# dtype: int64

# %%
# Drop the rows containing missng values

data.dropna(inplace=True)

# %%
# confirm if there are stll any missing values
data.isna().sum()
# Out:
# case        0
# site        0
# Pop         0
# sex         0
# age         0
# hdlngth     0
# skullw      0
# totlngth    0
# taill       0
# footlgth    0
# earconch    0
# eye         0
# chest       0
# belly       0
# dtype: int64

# %%
# check the shape of the data
data.shape
# Out:
# (101, 14)

# %% [markdown]
# ### **Descriptive Statistics**

# %%
data.describe(include= "all")
# Out:
#               case        site    Pop  sex         age     hdlngth  \
# count   101.000000  101.000000    101  101  101.000000  101.000000
# unique         NaN         NaN      2    2         NaN         NaN
# top            NaN         NaN  other    m         NaN         NaN
# freq           NaN         NaN     58   59         NaN         NaN
# mean     52.762376    3.673267    NaN  NaN    3.821782   92.730693
# std      30.573894    2.366892    NaN  NaN    1.915182    3.518714
# min       1.000000    1.000000    NaN  NaN    1.000000   82.500000
# 25%      26.000000    1.000000    NaN  NaN    2.000000   90.700000
# 50%      54.000000    4.000000    NaN  NaN    3.000000   92.900000
# 75%      79.000000    6.000000    NaN  NaN    5.000000   94.800000
# max     104.000000    7.000000    NaN  NaN    9.000000  103.100000
#
#             skullw    totlngth       taill    footlgth    earconch  \
# count   101.000000  101.000000  101.000000  101.000000  101.000000
# ...

# %%
data['age'].describe()
# Out:
# count    101.000000
# mean       3.821782
# std        1.915182
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        5.000000
# max        9.000000
# Name: age, dtype: float64

# %%
# for i in data[['age', 'skullw', 'totlngth']]:
    # print(i.describe())

# %%
data['hdlngth'].describe()
# Out:
# count    101.000000
# mean      92.730693
# std        3.518714
# min       82.500000
# 25%       90.700000
# 50%       92.900000
# 75%       94.800000
# max      103.100000
# Name: hdlngth, dtype: float64

# %%
data['skullw'].describe()
# Out:
# count    101.000000
# mean      56.960396
# std        3.102679
# min       50.000000
# 25%       55.000000
# 50%       56.400000
# 75%       58.100000
# max       68.600000
# Name: skullw, dtype: float64

# %%
data['totlngth'].describe()
# Out:
# count    101.000000
# mean      87.269307
# std        4.196802
# min       75.000000
# 25%       84.500000
# 50%       88.000000
# 75%       90.000000
# max       96.500000
# Name: totlngth, dtype: float64

# %%
data['taill'].describe()
# Out:
# count    101.000000
# mean      37.049505
# std        1.971681
# min       32.000000
# 25%       36.000000
# 50%       37.000000
# 75%       38.000000
# max       43.000000
# Name: taill, dtype: float64

# %%
data['earconch'].describe()
# Out:
# count    101.000000
# mean      48.133663
# std        4.060352
# min       41.300000
# 25%       44.800000
# 50%       46.800000
# 75%       52.000000
# max       56.200000
# Name: earconch, dtype: float64

# %%
data['eye'].describe()
# Out:
# count    101.000000
# mean      15.050495
# std        1.058643
# min       12.800000
# 25%       14.400000
# 50%       14.900000
# 75%       15.700000
# max       17.800000
# Name: eye, dtype: float64

# %%
data['chest'].describe()
# Out:
# count    101.000000
# mean      27.064356
# std        2.020722
# min       22.000000
# 25%       25.500000
# 50%       27.000000
# 75%       28.000000
# max       32.000000
# Name: chest, dtype: float64

# %%
data['belly'].describe()
# Out:
# count    101.000000
# mean      32.638614
# std        2.727745
# min       25.000000
# 25%       31.000000
# 50%       32.500000
# 75%       34.000000
# max       40.000000
# Name: belly, dtype: float64

# %%
# calculate mean and median 
# Filter for female
Sex= data[data['sex'] == 'f']
Sex
# print(np.mean())
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 1       2     1    Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2       3     1    Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3       4     1    Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4       5     1    Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
# 5       6     1    Vic   f  1.0     93.1    54.8      90.5   35.5      73.2
# 7       8     1    Vic   f  6.0     94.8    57.6      91.0   37.0      72.7
# 8       9     1    Vic   f  9.0     93.4    56.3      91.5   37.0      72.4
# 9      10     1    Vic   f  6.0     91.8    58.0      89.5   37.5      70.9
# 10     11     1    Vic   f  9.0     93.3    57.2      89.5   39.0      77.2
# 11     12     1    Vic   f  5.0     94.9    55.6      92.0   35.5      71.7
# 16     17     1    Vic   f  1.0     94.7    67.7      89.5   36.5      73.2
# ...

# %%
# Filter for sex = m
Age =data[data['sex'] == 'm']
Age
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0       1     1    Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 6       7     1    Vic   m  2.0     95.3    58.2      89.5   36.0      71.5
# 12     13     1    Vic   m  5.0     95.1    59.9      89.5   36.0      71.0
# 13     14     1    Vic   m  3.0     95.4    57.6      91.5   36.0      74.3
# 14     15     1    Vic   m  5.0     92.9    57.6      85.5   34.0      69.7
# 15     16     1    Vic   m  4.0     91.6    56.0      86.0   34.5      73.0
# 17     18     1    Vic   m  2.0     93.5    55.7      90.0   36.0      73.7
# 21     22     1    Vic   m  3.0     96.3    58.5      91.0   39.5      73.5
# 23     24     1    Vic   m  2.0     94.4    54.9      84.0   34.0      75.0
# 24     25     1    Vic   m  3.0     95.8    58.5      91.5   35.5      72.3
# 25     26     1    Vic   m  7.0     96.0    59.0      90.0   36.0      73.6
# ...

# %%
mean = Age["age"]
np.mean(mean)
# Out:
# np.float64(3.7288135593220337)

# %%
# mean for the age of both male and female
data.groupby('sex')['age'].mean()
# Out:
# sex
# f    3.952381
# m    3.728814
# Name: age, dtype: float64

# %%
# median for the eye of both male and female
data.groupby('sex')['eye'].median()
# Out:
# sex
# f    14.75
# m    15.00
# Name: eye, dtype: float64

# %%
# mean for the head length of both male and female
data.groupby('sex')['hdlngth'].mean()
# Out:
# sex
# f    92.238095
# m    93.081356
# Name: hdlngth, dtype: float64

# %%
# mean for the skull of both male and female
data.groupby('sex')['skullw'].mean()
# Out:
# sex
# f    56.578571
# m    57.232203
# Name: skullw, dtype: float64

# %%
#  median for age of both male and female
data.groupby('sex')['age'].median()
# Out:
# sex
# f    3.5
# m    3.0
# Name: age, dtype: float64

# %%
# median of hdlngth for both male and female
data.groupby('sex')['hdlngth'].median()
# Out:
# sex
# f    92.5
# m    93.3
# Name: hdlngth, dtype: float64

# %%
# median of skullw for both male and female
data.groupby('sex')['skullw'].median()
# Out:
# sex
# f    56.35
# m    56.60
# Name: skullw, dtype: float64

# %% [markdown]
# MEASURE OF SPREAD

# %%
variance_value = data['age'].var(ddof=0)
variance_value
# Out:
# np.float64(3.6316047446328796)

# %%
# standard Deviation 
std_dev_value = data['age'].std(ddof=0)
std_dev_value
# Out:
# np.float64(1.9056769780403182)

# %%
# Relative spread (coefficient of variation)
c_o_v= std_dev_value / mean
c_o_v
# Out:
# 0      0.238210
# 6      0.952838
# 12     0.381135
# 13     0.635226
# 14     0.381135
# 15     0.476419
# 17     0.952838
# 21     0.635226
# 23     0.952838
# 24     0.635226
# 25     0.272240
# 27     0.476419
# 30     0.635226
# 32     0.635226
# 33     0.952838
# 34     0.476419
# 35     0.272240
# 37     0.272240
# 41     0.635226
# 44     0.635226
# 46     0.952838
# 47     0.381135
# 48     0.476419
# 51     0.317613
# 53     0.272240
# 54     0.952838
# 55     0.635226
# 57     0.635226
# 58     0.952838
# 60     0.272240
# 66     0.476419
# 67     0.381135
# 68     0.381135
# 70     0.317613
# 71     1.905677
# 72     1.905677
# 74     0.317613
# 75     0.381135
# 76     0.317613
# 77     1.905677
# 78     1.905677
# 79     1.905677
# 80     0.635226
# 83     0.635226
# 84     0.635226
# 86     0.952838
# 88     0.317613
# 89     0.635226
# 90     0.635226
# 91     0.952838
# 92     0.635226
# 93     0.272240
# 94     0.476419
# 95     0.476419
# 96     0.635226
# ...

# %% [markdown]
# DETECTING OUTLIERS

# %%
# To remove outliers(lines)
def remove_outliers(lines):
    Q1= lines.quantile(0.25)
    Q3= lines.quantile(0.75)
    IQR= Q3 - Q1
    lower= Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return lines[(lines >= lower) & (lines <= upper)]

# %%
datas = data[(data['sex']=='m') & (data['age'] >= 1)]['hdlngth']
outcome = remove_outliers(datas)
outcome
# Out:
# 0      94.1
# 6      95.3
# 12     95.1
# 13     95.4
# 14     92.9
# 15     91.6
# 17     93.5
# 21     96.3
# 23     94.4
# 24     95.8
# 25     96.0
# 27     93.8
# 30     92.8
# 32     91.4
# 33     90.6
# 34     94.4
# 35     93.3
# 37     92.4
# 41     85.3
# 44     90.7
# 46     90.1
# 47     98.6
# 48     95.4
# 51     97.6
# 53     96.9
# 55     99.9
# 57     94.5
# 60     95.7
# 66     93.3
# 67     94.1
# 68     98.0
# 70     92.8
# 71     85.9
# 74     93.8
# 75     92.4
# 76     93.6
# 77     86.5
# 78     85.8
# 79     86.7
# 80     90.6
# 83     88.4
# 84     89.5
# 86     98.5
# 88     97.7
# 89     92.6
# 90     97.8
# 91     90.7
# 92     89.2
# 93     91.8
# 94     91.6
# 95     94.8
# 96     91.0
# 97     93.2
# 99     89.5
# 100    88.6
# 102    91.5
# Name: hdlngth, dtype: float64
